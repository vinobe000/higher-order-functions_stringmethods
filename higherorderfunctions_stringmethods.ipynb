# %%
def c_stringmethods(x):
  res=lambda x:x.capitalize()
  print(res(x))
  res2=lambda x:x.casefold()
  print(res2(x))
  res3=lambda x:x.center(50,"₹")
  print(res3(x))
  res4=lambda x:x.count("i")
  print(res4(x))

# %%
def e_stringmethods(x):
  res=x.encode(encoding="utf-32")
  print(res)
  res2=x.endswith("python")
  print(res2)

# %%
def f_stringmethods(x):
  res=x.find("i")
  print(res)

# %%
def format_stringmethods(x):
  res=x.format("is","core","python")
  print(res)

# %%
def ind_stringmethods(x):
  res=x.find("o")
  print(res)
